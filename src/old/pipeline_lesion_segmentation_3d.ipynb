# %% [markdown]
# # 3DRDNN
#
# Main pipeline for research in my Master.
#
# ## goals in this notebook
#
# Prepare the pipeline for any 3d DNN to train on CT data.
# 1) data loader
# 2) DNN
# 3) Training
# 4) Results comparison

# %%
# Testing reading GPU
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np

# Check TensorFlow Version
print("TensorFlow Version: {}".format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn("No GPU found. Please ensure you have installed TensorFlow correctly")
else:
    print(tf.test.gpu_device_name())
# Out:
# TensorFlow Version: 2.10.1
# /device:GPU:0

# %%
# datasets for tf
from data_preprocessing_3d import get_dataset_large

batch_size = 4
dataset = get_dataset_large(
    r"C:\Users\kaczm\programming\3DRDNN\data\LITS_TFRecords\train"
)
dataset = dataset.shuffle(8).batch(batch_size)
valid_dataset = get_dataset_large(
    r"C:\Users\kaczm\programming\3DRDNN\data\LITS_TFRecords\valid"
)
valid_dataset = valid_dataset.batch(
    batch_size
)  # .shuffle(1000,  reshuffle_each_iteration=True)

for sample in dataset.take(1):
    print(sample[0].shape)
    print(sample[1].shape)

for sample in valid_dataset.take(10):
    print(sample[0].shape)
    print(sample[1].shape)
    print(np.min(sample[0]))
    print(np.max(sample[0]))

print(dataset)
print(valid_dataset)
# Out:
# ['C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images0.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images1.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images2.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images3.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images4.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images5.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images6.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images7.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images8.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\train\\images9.tfrecords']
# ['C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\valid\\images10.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\valid\\images11.tfrecords', 'C:\\Users\\kaczm\\programming\\3DRDNN\\data\\LITS_TFRecords\\valid\\images12.tfrecords']
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 2)
# 0.0
# 1.0
# <BatchDataset element_spec=(TensorSpec(shape=(None, None, None, None, None), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, None, None, None), dtype=tf.float64, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, None, None, None, None), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, None, None, None), dtype=tf.float64, name=None))>

# %%
### learning rate schedule


def scheduler(epoch, lr):
    if epoch < 2:
        lr = 0.001
        return lr
    else:
        return lr * tf.math.exp(-0.05)

# %%
# Network set-up
from utils import models

model = models.model_call(model_name="3DUNET", pxz=32, px=64, features=32)

# %%
# Metrics and training

adam = tf.keras.optimizers.Adam(
    learning_rate=0.00001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam",
)
precision_all = tf.keras.metrics.Precision(thresholds=0.5)
precision = tf.keras.metrics.Precision(thresholds=0.5, class_id=1)
recall = tf.keras.metrics.Recall(thresholds=0.5, class_id=1)

model.compile(
    loss="categorical_crossentropy",
    optimizer=adam,
    metrics=[precision_all, precision, recall],
)
model.summary(positions=[0.33, 0.66, 0.78, 1.0])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape                    Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 64, 64, 1)]         0           []
#
#  conv3d (Conv3D)                (None, 32, 64, 64, 32)          896         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 64, 64, 32)         128         ['conv3d[0][0]']
#  alization)
#
#  conv3d_1 (Conv3D)              (None, 32, 64, 64, 64)          18496       ['batch_normalization[
#                                                                             0][0]']
#
#  max_pooling3d (MaxPooling3D)   (None, 16, 32, 32, 64)          0           ['conv3d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 32, 32, 64)         256         ['max_pooling3d[0][0]'
#  rmalization)                                                               ]
#
#  dropout (Dropout)              (None, 16, 32, 32, 64)          0           ['batch_normalization_
#                                                                             1[0][0]']
#
#  conv3d_2 (Conv3D)              (None, 16, 32, 32, 64)          110656      ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 32, 32, 64)         256         ['conv3d_2[0][0]']
#  rmalization)
#
#  conv3d_3 (Conv3D)              (None, 16, 32, 32, 128)         221312      ['batch_normalization_
#                                                                             2[0][0]']
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 8, 16, 16, 128)         0           ['conv3d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 16, 16, 128)         512         ['max_pooling3d_1[0][0
#  rmalization)                                                               ]']
#
#  dropout_1 (Dropout)            (None, 8, 16, 16, 128)          0           ['batch_normalization_
#                                                                             3[0][0]']
#
#  conv3d_4 (Conv3D)              (None, 8, 16, 16, 128)          442496      ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 16, 16, 128)         512         ['conv3d_4[0][0]']
#  rmalization)
#
#  conv3d_5 (Conv3D)              (None, 8, 16, 16, 256)          884992      ['batch_normalization_
#                                                                             4[0][0]']
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 4, 8, 8, 256)           0           ['conv3d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 4, 8, 8, 256)           1024        ['max_pooling3d_2[0][0
#  rmalization)                                                               ]']
#
#  dropout_2 (Dropout)            (None, 4, 8, 8, 256)            0           ['batch_normalization_
#                                                                             5[0][0]']
#
#  conv3d_6 (Conv3D)              (None, 4, 8, 8, 256)            1769728     ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 8, 8, 256)           1024        ['conv3d_6[0][0]']
#  rmalization)
#
#  conv3d_7 (Conv3D)              (None, 4, 8, 8, 512)            3539456     ['batch_normalization_
#                                                                             6[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 8, 16, 16, 512)         7078400     ['conv3d_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 16, 16, 768)          0           ['conv3d_transpose[0][
#                                                                             0]',
#                                                                              'conv3d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 16, 16, 768)          0           ['concatenate[0][0]']
#
#  conv3d_8 (Conv3D)              (None, 8, 16, 16, 256)          5308672     ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 16, 16, 256)         1024        ['conv3d_8[0][0]']
#  rmalization)
#
#  conv3d_9 (Conv3D)              (None, 8, 16, 16, 256)          1769728     ['batch_normalization_
#                                                                             7[0][0]']
#
#  conv3d_transpose_1 (Conv3DTran  (None, 16, 32, 32, 256)        1769728     ['conv3d_9[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 32, 32, 384)         0           ['conv3d_transpose_1[0
#                                                                             ][0]',
#                                                                              'conv3d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 32, 32, 384)         0           ['concatenate_1[0][0]'
#                                                                             ]
#
#  conv3d_10 (Conv3D)             (None, 16, 32, 32, 128)         1327232     ['dropout_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 32, 32, 128)        512         ['conv3d_10[0][0]']
#  rmalization)
#
#  conv3d_11 (Conv3D)             (None, 16, 32, 32, 128)         442496      ['batch_normalization_
#                                                                             9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 32, 32, 128)        512         ['conv3d_11[0][0]']
#  ormalization)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 32, 64, 64, 128)        442496      ['batch_normalization_
#  spose)                                                                     10[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 64, 64, 192)         0           ['conv3d_transpose_2[0
#                                                                             ][0]',
#                                                                              'conv3d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 64, 64, 192)         0           ['concatenate_2[0][0]'
#                                                                             ]
#
#  conv3d_12 (Conv3D)             (None, 32, 64, 64, 64)          331840      ['dropout_5[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 64, 64, 64)         256         ['conv3d_12[0][0]']
#  ormalization)
#
#  conv3d_13 (Conv3D)             (None, 32, 64, 64, 64)          110656      ['batch_normalization_
#                                                                             11[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 32, 64, 64, 2)           130         ['conv3d_13[0][0]']
#
# ==================================================================================================
# Total params: 25,575,426
# Trainable params: 25,572,418
# Non-trainable params: 3,008
# __________________________________________________________________________________________________

# %%
# Results
# reading checkpoint if needen
#
#################################
import pandas as pd
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TerminateOnNaN,
)

# training
callbacks = [
    # EarlyStopping(patience=10, verbose=1),
    # ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.0000001, verbose=1),
    tf.keras.callbacks.LearningRateScheduler(scheduler),
    ModelCheckpoint(
        "models\\3DUNET_lesion_32_32_64\\epoch-{epoch:02d}-valloss-{val_loss:.4f}-{val_precision_1:.2f}-{val_recall:.2f}.hdf5",
        verbose=1,
        save_best_only=False,
        save_weights_only=True,
    ),
    TerminateOnNaN(),
]
epochs = 30

history = model.fit(
    dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=callbacks,
    initial_epoch=0,
)


hist_df = pd.DataFrame(history.history)

# save to json:
hist_json_file = "history.json"
with open(hist_json_file, mode="w") as f:
    hist_df.to_json(f)

# or save to csv:
hist_csv_file = "history.csv"
with open(hist_csv_file, mode="w") as f:
    hist_df.to_csv(f)
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[202], line 28
#      14 callbacks = [
#      15     # EarlyStopping(patience=10, verbose=1),
#      16     #ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.0000001, verbose=1),
#    (...)
#      24     TerminateOnNaN(),
#      25 ]
#      26 epochs = 30
# ---> 28 history = model.fit(
#      29     dataset,
#      30     epochs=epochs,
#      31     validation_data=valid_dataset,
#      32     callbacks=callbacks,
#      33     initial_epoch=0
#      34 )
#      37 hist_df = pd.DataFrame(history.history)
#      39 # save to json:
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, _, filtered_flat_args = \
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:2955, in Function.__call__(self, *args, **kwargs)
#    2952 """Calls a graph function specialized to the inputs."""
#    2953 with self._lock:
#    2954   (graph_function,
# -> 2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\func_graph.py:1136, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1134 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1135 try:
# -> 1136   return autograph.converted_call(
#    1137       original_func,
#    1138       args,
#    1139       kwargs,
#    1140       options=autograph.ConversionOptions(
#    1141           recursive=True,
#    1142           optional_features=autograph_options,
#    1143           user_requested=True,
#    1144       ))
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_fileldo_vjkr.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\training.py:1010, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1007   run_step = tf.function(
#    1008       run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009 data = next(iterator)
# -> 1010 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011 outputs = reduce_per_replica(
#    1012     outputs, self.distribute_strategy, reduction='first')
#    1013 return outputs
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\training.py:1000, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     999 def run_step(data):
# -> 1000   outputs = model.train_step(data)
#    1001   # Ensure counter is updated only if `train_step` succeeds.
#    1002   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\training.py:864, in Model.train_step(self, data)
#     862 # Run backwards pass.
#     863 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
# --> 864 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\training.py:957, in Model.compute_metrics(***failed resolving arguments***)
#     922 """Update metric states and collect all metrics to be returned.
#     923
#     924 Subclasses can optionally override this method to provide custom metric
#    (...)
#     954   `{'loss': 0.2, 'accuracy': 0.7}`.
#     955 """
#     956 del x  # The default implementation does not use `x`.
# --> 957 self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     958 # Collect metrics to return
#     959 return_metrics = {}
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\engine\compile_utils.py:459, in MetricsContainer.update_state(self, y_true, y_pred, sample_weight)
#     457   if metric_obj is None:
#     458     continue
# --> 459   metric_obj.update_state(y_t, y_p, sample_weight=mask)
#     461 for weighted_metric_obj in weighted_metric_objs:
#     462   if weighted_metric_obj is None:
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\utils\metrics_utils.py:70, in update_state_wrapper.<locals>.decorated(metric_obj, *args, **kwargs)
#      64     raise ValueError(
#      65         'Trying to run metric.update_state in replica context when '
#      66         'the metric was not created in TPUStrategy scope. '
#      67         'Make sure the keras Metric is created in TPUstrategy scope. ')
#      69 with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 70   update_op = update_state_fn(*args, **kwargs)
#      71 if update_op is not None:  # update_op will be None in eager execution.
#      72   metric_obj.add_update(update_op)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\metrics.py:178, in Metric.__new__.<locals>.update_state_fn(*args, **kwargs)
#     176 control_status = tf.__internal__.autograph.control_status_ctx()
#     177 ag_update_state = tf.__internal__.autograph.tf_convert(obj_update_state, control_status)
# --> 178 return ag_update_state(*args, **kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\metrics.py:1533, in Recall.update_state(self, y_true, y_pred, sample_weight)
#    1519 def update_state(self, y_true, y_pred, sample_weight=None):
#    1520   """Accumulates true positive and false negative statistics.
#    1521
#    1522   Args:
#    (...)
#    1531     Update op.
#    1532   """
# -> 1533   return metrics_utils.update_confusion_matrix_variables(
#    1534       {
#    1535           metrics_utils.ConfusionMatrix.TRUE_POSITIVES: self.true_positives,
#    1536           metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives
#    1537       },
#    1538       y_true,
#    1539       y_pred,
#    1540       thresholds=self.thresholds,
#    1541       thresholds_distributed_evenly=self._thresholds_distributed_evenly,
#    1542       top_k=self.top_k,
#    1543       class_id=self.class_id,
#    1544       sample_weight=sample_weight)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\keras\utils\metrics_utils.py:606, in update_confusion_matrix_variables(variables_to_update, y_true, y_pred, thresholds, top_k, class_id, sample_weight, multi_label, label_weights, thresholds_distributed_evenly)
#     596 if invalid_keys:
#     597   raise ValueError(
#     598       f'Invalid keys: "{invalid_keys}". '
#     599       f'Valid variable key options are: "{list(ConfusionMatrix)}"')
#     601 with tf.control_dependencies([
#     602     tf.compat.v1.assert_greater_equal(
#     603         y_pred,
#     604         tf.cast(0.0, dtype=y_pred.dtype),
#     605         message='predictions must be >= 0'),
# --> 606     tf.compat.v1.assert_less_equal(
#     607         y_pred,
#     608         tf.cast(1.0, dtype=y_pred.dtype),
#     609         message='predictions must be <= 1')
#     610 ]):
#     611   if sample_weight is None:
#     612     y_pred, y_true = losses_utils.squeeze_or_expand_dimensions(
#     613         y_pred, y_true)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\ops\check_ops.py:998, in assert_less_equal(x, y, data, summarize, message, name)
#     993 @tf_export(v1=['debugging.assert_less_equal', 'assert_less_equal'])
#     994 @dispatch.add_dispatch_support
#     995 @deprecation.deprecated_endpoints('assert_less_equal')
#     996 @_binary_assert_doc('<=', '[1, 3]')
#     997 def assert_less_equal(x, y, data=None, summarize=None, message=None, name=None):
# --> 998   return _binary_assert('<=', 'assert_less_equal', math_ops.less_equal,
#     999                         np.less_equal, x, y, data, summarize, message, name)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\ops\check_ops.py:425, in _binary_assert(sym, opname, op_func, static_func, x, y, data, summarize, message, name)
#     423   condition_static = np.all(static_func(x_static, y_static))
#     424   _assert_static(condition_static, data)
# --> 425 return control_flow_ops.Assert(condition, data, summarize=summarize)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\tf_should_use.py:243, in should_use_result.<locals>.decorated.<locals>.wrapped(*args, **kwargs)
#     242 def wrapped(*args, **kwargs):
# --> 243   return _add_should_use_warning(fn(*args, **kwargs),
#     244                                  warn_in_eager=warn_in_eager,
#     245                                  error_in_function=error_in_function)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:165, in Assert(condition, data, summarize, name)
#     162   return
#     164 with ops.name_scope(name, "Assert", [condition, data]) as name:
# --> 165   xs = ops.convert_n_to_tensor(data)
#     166   if all(x.dtype in {dtypes.string, dtypes.int32} for x in xs):
#     167     # As a simple heuristic, we assume that string and int32 are
#     168     # on host to avoid the need to use cond. If it is not case,
#     169     # we will pay the price copying the tensor to host memory.
#     170     return gen_logging_ops._assert(condition, data, summarize, name="Assert")
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:1790, in convert_n_to_tensor(values, dtype, name, preferred_dtype)
#    1767 def convert_n_to_tensor(values, dtype=None, name=None, preferred_dtype=None):
#    1768   """Converts `values` to a list of `Tensor` objects.
#    1769
#    1770   Args:
#    (...)
#    1788       value.
#    1789   """
# -> 1790   return internal_convert_n_to_tensor(
#    1791       values=values,
#    1792       dtype=dtype,
#    1793       name=name,
#    1794       preferred_dtype=preferred_dtype,
#    1795       as_ref=False)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:1757, in internal_convert_n_to_tensor(values, dtype, name, as_ref, preferred_dtype, ctx)
#    1754 for i, value in enumerate(values):
#    1755   n = None if name is None else "%s_%d" % (name, i)
#    1756   ret.append(
# -> 1757       convert_to_tensor(
#    1758           value,
#    1759           dtype=dtype,
#    1760           name=n,
#    1761           as_ref=as_ref,
#    1762           preferred_dtype=preferred_dtype,
#    1763           ctx=ctx))
#    1764 return ret
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:1695, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1690       raise TypeError("convert_to_tensor did not convert to "
#    1691                       "the preferred dtype: %s vs %s " %
#    1692                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1694 if ret is None:
# -> 1695   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1697 if ret is NotImplemented:
#    1698   continue
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\constant_op.py:343, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     340 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
# --> 693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3773 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3774 # Session.run call cannot occur between creating and mutating the op.
#    3775 with self._mutation_lock():
# -> 3776   ret = Operation(
#    3777       node_def,
#    3778       self,
#    3779       inputs=inputs,
#    3780       output_types=dtypes,
#    3781       control_inputs=control_inputs,
#    3782       input_types=input_types,
#    3783       original_op=self._default_original_op,
#    3784       op_def=op_def)
#    3785   self._create_op_helper(ret, compute_device=compute_device)
#    3786 return ret
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169   if op_def is None:
#    2170     op_def = self._graph._get_op_def(node_def.op)
# -> 2171   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                             control_input_ops, op_def)
#    2173   name = compat.as_str(node_def.name)
#    2175 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaczm\.conda\envs\tf2.8\lib\site-packages\tensorflow\python\framework\ops.py:2010, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2006   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    2007                                          serialized)
#    2009 try:
# -> 2010   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011 except errors.InvalidArgumentError as e:
#    2012   # Convert to ValueError for backwards compatibility.
#    2013   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

np.save("3Dunet_history_lesion.npy", np.array(history))
# Out:
# INFO:tensorflow:Assets written to: ram://ad702f97-a4e1-4759-9d76-acc0a704cf80/assets

# %%
# a zrób testowy trening od modelu do wątroby :))) mnoże będzie lepiej!

# %%
model.load_weights(r"models\\3DUNET_lesion_32_32_64\\epoch-23-valloss-0.0288-0.72-0.74.hdf5")
#model.load_weights(
#    r"models\\3DUNET_lesion_32_32_64\\epoch-27-valloss-0.0158-0.69-0.77.hdf5"
#)


# model.evaluate(valid_dataset)

# %%
# let's start with normal image and make some predictions

import SimpleITK as sitk
import glob
from tqdm import tqdm

# load .nii file

# def few funtion to make predictions, WIP, they will be later added to Nii class


def preprocessing_3d(t1) -> np.ndarray:
    min = -200
    max = 200
    t1 = np.where(t1 < min, min, t1)
    t1 = np.where(t1 > max, max, t1)
    t1 -= min
    return t1 / max


def label_seperator_liver(img):
    img = np.where(img == 2, 1, img)
    return img


def label_seperator_lesion(img):
    img = np.where(img == 1, 0, img)
    img = np.where(img == 2, 1, img)
    return img


def reading_data(path: str) -> np.ndarray:
    sitk_t1 = sitk.ReadImage(path)
    t1 = sitk.GetArrayFromImage(sitk_t1)
    t1 = t1.reshape(t1.shape[0], t1.shape[1], t1.shape[2], 1)

    t1 = tf.dtypes.cast(t1, tf.float32)

    return t1


def label_seperator_liver(img):
    img = np.where(img == 2, 1, img)
    return img


path = "data\\LITS_Challenge\\Training_Batch_1"
files_volume = glob.glob(path + "\\volume*.nii")
files_segmenation = glob.glob(path + "\\segmentation*.nii")

print(files_volume[12])
print(files_segmenation[0])
# Out:
# data\LITS_Challenge\Training_Batch_1\volume-2.nii
# data\LITS_Challenge\Training_Batch_1\segmentation-0.nii

# %%
file_id = 8
volume_1 = reading_data(files_volume[file_id])
volume_1 = preprocessing_3d(volume_1)
print(np.min(volume_1))
print(np.max(volume_1))


seg_1 = reading_data(files_segmenation[file_id])
liver_1 = label_seperator_liver(seg_1)
seg_1 = label_seperator_lesion(seg_1)
seg_1 = tf.keras.utils.to_categorical(seg_1, 2)
print(volume_1.shape)
print(liver_1.shape)
print(seg_1.shape)


volume_1 = np.where(liver_1 > 0, volume_1, 0)
# Out:
# 0.0
# 2.0
# (689, 512, 512, 1)
# (689, 512, 512, 1)
# (689, 512, 512, 2)

# %%
# 1) going from top to the bottom, all slices even without the liver
# data preparation -> spreading data to quboids

def get_prediction(volume_1,seg_1):
    n = (volume_1.shape[0] // 32) * 2 - 1
    m = (volume_1.shape[1] // 64) * 2 - 1

    chunk_size = 32
    cords_shift = chunk_size // 2

    #print(chunk_size)
    #print(cords_shift)

    total_q = n * m * m  # total quboids

    all_quboids = np.zeros(
        (int(total_q // 4 + 1), 4, chunk_size, chunk_size * 2, chunk_size * 2, 1)
    )
    all_quboids_seg = np.zeros(
        (int(total_q // 4 + 1), 4, chunk_size, chunk_size * 2, chunk_size * 2, 2)
    )
    preds = np.zeros(
        (int(total_q // 4 + 1), 4, chunk_size, chunk_size * 2, chunk_size * 2, 2)
    )
    #print(all_quboids.shape)
    batch_no = 0
    q = 0
    for z in range(n):  # z direction
        for y in range((m)):
            for x in range((m)):
                tmp_image = volume_1[
                    z * cords_shift : z * cords_shift + chunk_size,
                    y * cords_shift * 2 : y * cords_shift * 2 + chunk_size * 2,
                    x * cords_shift * 2 : x * cords_shift * 2 + chunk_size * 2,
                    0:1,
                ]

                tmp_seg = seg_1[
                    z * cords_shift : z * cords_shift + chunk_size,
                    y * cords_shift * 2 : y * cords_shift * 2 + chunk_size * 2,
                    x * cords_shift * 2 : x * cords_shift * 2 + chunk_size * 2,
                    0:2,
                ]

                all_quboids[batch_no, q, :, :, :, 0:1] = tmp_image
                all_quboids_seg[batch_no, q, :, :, :, 0:2] = tmp_seg
                q += 1
                if q > 3:
                    batch_no += 1
                    q = 0

                """
                tmp_seg = seg_1[
                    z * cords_shift : z * cords_shift + chunk_size,
                    y * cords_shift * 2 : y * cords_shift * 2 + chunk_size * 2,
                    x * cords_shift * 2 : x * cords_shift * 2 + chunk_size * 2,
                    0:2,
                ]"""


    # prediction for whole


    for i in tqdm(range(len(all_quboids))):
        if np.any(all_quboids[i] > 0):
            preds[i] = model.predict(all_quboids[i],verbose=0)

    #print(preds.shape)
    #print("done")

    a = 0
    final_preds = np.zeros((np.shape(seg_1)))
    #print(final_preds.shape)
    i = 0
    j = 0
    for z in range(n):  # z direction
        for y in range((m)):
            for x in range((m)):
                final_preds[
                    z * cords_shift: z * cords_shift + chunk_size,
                    y * cords_shift * 2: y * cords_shift * 2 + chunk_size * 2,
                    x * cords_shift * 2: x * cords_shift * 2 + chunk_size * 2,
                    0:2,
                ] += preds[i, j, :, :, :, 0:2]
                j += 1
                if j > 3:
                    i += 1
                    j = 0

                a += 1


    final_preds = final_preds / 8
    return final_preds

# %%
def get_metrics(liver,gt,preds,thresholds=0.5):
    TP = tf.keras.metrics.TruePositives(thresholds=thresholds)
    FP = tf.keras.metrics.FalsePositives(thresholds=thresholds)
    FN = tf.keras.metrics.FalseNegatives(thresholds=thresholds)
    
    preds = preds[:,:,:,1]
    preds = np.where(liver[:,:,:,0]>0,preds,0)

    TP.update_state(gt[:, :, :, 1], preds)
    FP.update_state(gt[:, :, :, 1], preds)
    FN.update_state(gt[:, :, :, 1], preds)

    prec = TP.result() / (TP.result() + FP.result())
    recall = TP.result() / (TP.result() + FN.result())
    return prec, recall

# %%
plt.rcParams["figure.figsize"] = (20, 15)

for i in range(np.shape(volume_1)[0]):
    if np.any(volume_1[i, :, :, 0]) > 0 and np.any(seg_1[i, :, :, 1]) > 0.1:

        plt.subplot(1, 3, 1)
        plt.imshow(volume_1[i, :, :, 0])
        plt.title("original volume")
        plt.grid()
        plt.subplot(1, 3, 2)
        plt.title("combined predictions")
        plt.imshow(lesion[i, :, :], vmin=0.07, vmax=0.2)
        plt.grid()
        plt.subplot(1, 3, 3)
        plt.title("ground truth")
        plt.imshow(seg_1[i, :, :, 1])
        plt.grid()
        plt.suptitle(f"{volume_1.shape[0]}_{i}, precition:{np.round(prec,2)} recall {np.round(recall,2)}")
        plt.savefig(f"results_images/{volume_1.shape[0]}_{i}.png")
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 threshold = 0.27
# ----> 2 prec, recall = get_metrics(volume_1,seg_1,final_preds,threshold)
#       3 print(prec)
#       4 print(recall)
#
# Cell In[46], line 7, in get_metrics(liver, gt, preds, thresholds)
#       4 FN = tf.keras.metrics.FalseNegatives(thresholds=threshold)
#       6 preds = preds[:,:,:,1]
# ----> 7 preds = np.where(liver[:,:,:,0]>0,preds,0)
#       9 TP.update_state(gt[:, :, :, 1], preds)
#      10 FP.update_state(gt[:, :, :, 1], preds)
#
# File <__array_function__ internals>:5, in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (75,512,512) (517,512,512) ()

# %%
# Metrics loop

plotting = False
idxxxx = [8,9,12]
for file_id in idxxxx:

    #file_id = 8


    threshold = 0.3

    volume_1 = reading_data(files_volume[file_id])
    volume_1 = preprocessing_3d(volume_1)


    seg_1 = reading_data(files_segmenation[file_id])
    liver_1 = label_seperator_liver(seg_1)
    seg_1 = label_seperator_lesion(seg_1)
    seg_1 = tf.keras.utils.to_categorical(seg_1, 2)
    volume_1 = np.where(liver_1 > 0, volume_1, 0)
    print("get volume is ok")
    final_preds = get_prediction(volume_1,seg_1)
    print("preds are ok")

    plt.rcParams["figure.figsize"] = (20, 15)

    lesion = final_preds[:, :, :, 0:1]
    lesion = np.where(liver_1 > 0, final_preds, 0)
    lesion = lesion[:, :, :, 1]

    print("lesion is ok")
    prec, recall = get_metrics(volume_1,seg_1,final_preds,threshold)
    print("metrics are ok")

    # lesion = np.where(lesion>threshold,1,0)
    if plotting:
        for i in range(np.shape(volume_1)[0]):
            if np.any(volume_1[i, :, :, 0]) > 0 and np.any(seg_1[i, :, :, 1]) > 0.1:

                plt.subplot(1, 3, 1)
                plt.imshow(volume_1[i, :, :, 0])
                plt.title("original volume")
                plt.grid()
                plt.subplot(1, 3, 2)
                plt.title("combined predictions")
                plt.imshow(lesion[i, :, :], vmin=threshold, vmax=threshold+0.01)
                plt.grid()
                plt.subplot(1, 3, 3)
                plt.title("ground truth")
                plt.imshow(seg_1[i, :, :, 1])
                plt.grid()
                plt.suptitle(f"{file_id}_{volume_1.shape[0]}_{i}, precition:{np.round(prec,2)} recall {np.round(recall,2)}")
                plt.savefig(f"results_images/{file_id}_{volume_1.shape[0]}_{i}.png")
                plt.close()



    #with open("results.txt",'a+') as f:
    #    f.write(f"file_id: {file_id}, z: {volume_1.shape[0]}, prec: {np.round(prec,2)}, recall: {np.round(recall,2)}\n")

    print(prec, recall)
    np.save(f"{file_id}_preds.npy",final_preds)
    del volume_1
    del seg_1
    del final_preds
    
    print(f"done {file_id} and saved")
# Out:
# get volume is ok
# 100%|██████████| 2307/2307 [01:03<00:00, 36.60it/s]
# preds are ok
# lesion is ok
# metrics are ok
# tf.Tensor(0.82719815, shape=(), dtype=float32) tf.Tensor(0.855562, shape=(), dtype=float32)
# done 8 and saved
# get volume is ok
# 100%|██████████| 2757/2757 [00:51<00:00, 53.95it/s]
# preds are ok
# lesion is ok
# metrics are ok
# tf.Tensor(0.6348246, shape=(), dtype=float32) tf.Tensor(0.97436035, shape=(), dtype=float32)
# done 9 and saved
# get volume is ok
# 100%|██████████| 1744/1744 [00:41<00:00, 41.61it/s]
# preds are ok
# lesion is ok
# metrics are ok
# tf.Tensor(0.74722224, shape=(), dtype=float32) tf.Tensor(0.81855494, shape=(), dtype=float32)
# done 12 and saved

# %% [markdown]
# file_id: 0, z: 75, prec: 0.07000000029802322, recall: 0.0
#
# file_id: 1, z: 123, prec: 0.5199999809265137, recall: 0.23000000417232513
#
# file_id: 2, z: 501, prec: 0.5799999833106995, recall: 0.949999988079071
#
# file_id: 3, z: 466, prec: 0.6399999856948853, recall: 0.8199999928474426
#
# file_id: 4, z: 455, prec: 0.11999999731779099, recall: 0.3700000047683716
#
# file_id: 5, z: 605, prec: 0.07000000029802322, recall: 0.6600000262260437
#
# file_id: 6, z: 588, prec: 0.3100000023841858, recall: 0.8100000023841858
#
# file_id: 7, z: 565, prec: 0.0, recall: 0.0
#
# file_id: 8, z: 689, prec: 0.8600000143051147, recall: 0.8500000238418579
#
# file_id: 9, z: 826, prec: 0.699999988079071, recall: 0.9800000190734863
#
# file_id: 10, z: 845, prec: 0.7599999904632568, recall: 0.6800000071525574
#
# file_id: 11, z: 547, prec: 0.30000001192092896, recall: 0.7200000286102295
#
# file_id: 12, z: 517, prec: 0.7699999809265137, recall: 0.7900000214576721
#
# file_id: 13, z: 574, prec: 0.019999999552965164, recall: 0.4300000071525574
#
# file_id: 14, z: 437, prec: 0.7699999809265137, recall: 0.2199999988079071
#
# file_id: 15, z: 247, prec: 0.47999998927116394, recall: 0.9900000095367432
#
# file_id: 16, z: 391, prec: 0.5, recall: 1.0
#
# file_id: 17, z: 276, prec: 0.0, recall: 0.0
#
# file_id: 18, z: 601, prec: 0.1599999964237213, recall: 0.8600000143051147
#
# file_id: 19, z: 668, prec: 0.6899999976158142, recall: 0.9900000095367432
#
# file_id: 20, z: 861, prec: 0.6200000047683716, recall: 0.9399999976158142
#
# file_id: 21, z: 534, prec: 0.33000001311302185, recall: 0.8100000023841858
#
# file_id: 22, z: 841, prec: 0.75, recall: 0.9900000095367432
#
# file_id: 23, z: 537, prec: 0.0, recall: 0.0
#
# file_id: 24, z: 518, prec: 0.550000011920929, recall: 0.9900000095367432
#
# file_id: 25, z: 541, prec: 0.6100000143051147, recall: 0.9900000095367432
#
# file_id: 26, z: 541, prec: 0.5799999833106995, recall: 0.9700000286102295
#
# file_id: 27, z: 549, prec: 0.5400000214576721, recall: 0.9900000095367432

# %%
# 2) only part with the liver




#TODO

# 1) zdefiniować liczenie metryk (tj metryki i z czego mają się liczyć)
# 2) przeliczyć dla każdego skanu
# 3) przeskalować małe skany na duże i przeliczyć znowu
# 4) pomyśleć jak można sprawdzać dice od wielkości

# %% [markdown]
# Wnioski:
#
#
# - działa, cały pipeline działa
# - sieć wymaga modyfikacji do tego podejścia
#
# - wykrywa poprawie większe zmiany, nie wykrywa małych, jest to związane z architekturą sieci
# -- do tego problemu trzeba to zrobić inaczej, więcej kanałów na normalnym poziomie, mniej na niższym, ew zrobić nawet jednopoziomowy encoder dekoder (i więcej cech)
# - podejście nie wydaje się złe, tylko wymaga faktycznie dostosowania pod siebie kilku aspektów, szczególnie do szuaknia małych zmian

# %%
from skimage.measure import find_contours, label, regionprops
from tifffile import TiffFile, imwrite
from roifile import ImagejRoi
import cv2
def plot_image_overlays(image, overlays, **kwargs):
    """Plot image and overlays (bytes) using matplotlib."""
    fig, ax = plt.subplots()
    ax.imshow(image, cmap='gray')
    if not isinstance(overlays, list):
        overlays = [overlays]
    for overlay in overlays:
        roi = ImagejRoi.frombytes(overlay)
        roi.plot(ax, **kwargs)
    plt.show()

# %%
slices = [425,400]#,450]
idxxxx = [8,9]#,12]
for i,file_id in enumerate(idxxxx):
    volume_1 = reading_data(files_volume[file_id])
    print(volume_1.shape)
    volume_1 = preprocessing_3d(volume_1)
    seg_1 = reading_data(files_segmenation[file_id])
    seg_1 = label_seperator_lesion(seg_1)
    seg_1 = tf.keras.utils.to_categorical(seg_1, 2)
    one_slice = slices[i]
    lesion = np.load(f"{file_id}_preds.npy")
    AA = np.where(lesion[one_slice, :, :,1]>0.3,1,0)
    
    print(AA.shape)
    for j in range(0,len(seg_1)):
        if j != one_slice:
            imwrite(f"tmp_tiff{i+1}/{file_id}_roi_test_{j}.tif", volume_1[j, :, :, 0], imagej=True)


        else:
            overlays = []
            found_contours = find_contours(AA, level=0.9999)
            for contour in found_contours:
                empty_list = []
                c = np.expand_dims(contour.astype(np.float32), 1)
                
                # Convert it to UMat object
                c = cv2.UMat(c)
                area = cv2.contourArea(c)
                if area > 80:
                    overlays.append(ImagejRoi.frompoints(np.round(contour)[:, ::-1]).tobytes())
                    print(area,"ok countur")
                else:
                    print(area,"regected")
                
            #print(overlays)


            """volume_1[slice, :, :, 0]
            lesion[slice, :, :]
            """

            plot_image_overlays(volume_1[slice, :, :, 0], overlays, lw=5)

            # write the image and overlays to a new ImageJ TIFF file
            imwrite(f"tmp_tiff{i+1}/{file_id}_roi_test_{j}.tif", volume_1[j, :, :, 0], imagej=True, metadata={'Overlays': overlays})
            print("aaa")
# Out:
# (689, 512, 512, 1)
# (512, 512)
# 870.0123214941705 ok countur
# 6707.537467976974 ok countur
# 63.49668886559084 regected
# 2.2817403078079224e-08 regected
# 0.0001983854454010725 regected
# 20.998077415395528 regected
# 194.50430299527943 ok countur
# aaa
# (826, 512, 512, 1)
# (512, 512)
# 674.0093155119102 ok countur
# 2.1187588572502136e-08 regected
# 1016.01105501235 ok countur
# 0.000198382418602705 regected
# 0.000198382418602705 regected
# 1.816079020500183e-08 regected
# 1.816079020500183e-08 regected
# 1.816079020500183e-08 regected
# 0.000198382418602705 regected
# aaa
